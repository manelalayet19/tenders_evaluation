# %%
pip install openai
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.2 kB ? eta -:--:--
#      ---------------------------------------- 60.2/60.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/77.0 kB ? eta -:--:--
#    ---------------------------------------- 77.0/77.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
# ...

# %%
import openai 
from dotenv import dotenv_values
import pandas as pd 
config = dotenv_values('.env')
openai.api_key = config['OPEN_AI_API']
def complete(prompt , temperature=0.7 , stop=None, max_tokens=500) : 
    response = openai.ChatCompletion.create(
        model = 'gpt-3.5-turbo', 
        messages = [
            {
                'role' :'user', 
                'content' : prompt
            }
        ], 
        temperature = temperature, 
        max_tokens = max_tokens , 
        stop = stop , 
        top_p = 0.7 , 
        frequency_penalty = 0 , 
        presence_penalty = 0 , 

    )
    result = response.choices[0]['message']['content']
    return result

# %%
print(complete("""
         step 1 : msummarize  the text and provided. 

         step 2 the summarized text should be in a list with clear context in case you need help in providing a reliable response ask for context  

         ***text *** : 
•	Scientific rigour : We are able to provide a quality service for the implementation of best practices in data analysis, modelling and rigorous assessment of economic and health impacts.
•	Collaborative approach : We develop your projects in a multidisciplinary framework within the community of researchers and health stakeholders.
•	Personalized support : We share information and experiences continuously in order to evaluate and constantly improve our performance and the performance of your projects.
•	Ethics and safety : Taking into account ethical recommendations and securing data is at the heart of our customer approach.
•	Innovative Solutions: Leverage our analytics and data collection capabilities to offer novel solutions for impact assessment and targeting of development assistance programs.
•	Data-Driven Strategies: Provide steadfast support and monitoring to ensure the effectiveness of formulated strategies for all stakeholders.
•	Academic and Research Collaboration: Foster collaborative research with academic institutions and research centers, especially from developing countries.
•	Multidisciplinary Context: Integrate economic theories with empirical data and sectoral knowledge to provide a well-rounded perspective on tackled problematics.
•	Capacity Building: Equip national statistical offices and public sector agencies with the skills and tools needed for effective data collection and analysis. Utilize our network of international experts and researchers to enhance the capabilities of developing countries.
•	Quality Assessments: Conduct robust evaluations of policies and programs to gauge their impact on poverty, healthcare, and labor markets.
•	Data-Driven Decision Making: Utilize data analytics and geospatial data to facilitate targeted and effective policy interventions.
•	Inclusivity and Equity: Focus on gender studies, intra-household inequalities, and social protection to ensure that our assessments and solutions are inclusive and equitable.
•	Global Reach: Expand our impact by engaging with international organizations and governments, particularly in developing countries, to implement effective poverty reduction and social protection strategies.
•	Human Development: Implement innovative interventions and efficient redistributive mechanisms targeting poor, vulnerable, or diseased populations.
•	Policy Assessment and Implementation: Assist international organizations and governments in understanding and assessing the impact of policies and programs.
•	Publication and Knowledge Dissemination: Produce high-quality research publications to further enrich the field of development economics and healthcare.

instrunction: the goals should be starting with verbs , numeric list. 
exemple :  
1. Increase number of projects
2. diversify existing portfolio of projects (a lot of projects lately are in sustainable climate practices)
3. Collaborate on projects (as a way to make connections and show our work on platforms etc)
4. Find long-term projects or projects that can lead to other projects (more lucrative)
5. Improve visibility in target sphere
         
instruction : need to be the sumarry of the text provide previously responding to te criteria we defined.
 you can provide the first exemple and a second one and compare their similarity in regards of their meaning
and context. provide reliable results. 
final step that summary should be summarized

output : 
        numeric list 
        provide two exemples 
         
         """))
# Out:
# Summary:
#
# 1. Implement best practices in data analysis, modelling and rigorous assessment of economic and health impacts.
# 2. Develop projects in a multidisciplinary framework within the community of researchers and health stakeholders.
# 3. Provide continuous information sharing and performance evaluation for project improvement.
# 4. Uphold ethical recommendations and secure data in customer approach.
# 5. Offer innovative solutions for impact assessment and development assistance programs.
# 6. Ensure effectiveness of formulated strategies through steadfast support and monitoring.
# 7. Foster collaborative research with academic institutions and research centers.
# 8. Integrate economic theories with empirical data for a well-rounded perspective on tackled problematics.
# 9. Equip public sector agencies with effective data collection and analysis skills.
# 10. Conduct robust evaluations of policies and programs to gauge their impact.
# ...

# %%
sammary = """

•	Scientific rigour : We are able to provide a quality service for the implementation of best practices in data analysis, modelling and rigorous assessment of economic and health impacts.
•	Collaborative approach : We develop your projects in a multidisciplinary framework within the community of researchers and health stakeholders.
•	Personalized support : We share information and experiences continuously in order to evaluate and constantly improve our performance and the performance of your projects.
•	Ethics and safety : Taking into account ethical recommendations and securing data is at the heart of our customer approach.
•	Innovative Solutions: Leverage our analytics and data collection capabilities to offer novel solutions for impact assessment and targeting of development assistance programs.
•	Data-Driven Strategies: Provide steadfast support and monitoring to ensure the effectiveness of formulated strategies for all stakeholders.
•	Academic and Research Collaboration: Foster collaborative research with academic institutions and research centers, especially from developing countries.
•	Multidisciplinary Context: Integrate economic theories with empirical data and sectoral knowledge to provide a well-rounded perspective on tackled problematics.
•	Capacity Building: Equip national statistical offices and public sector agencies with the skills and tools needed for effective data collection and analysis. Utilize our network of international experts and researchers to enhance the capabilities of developing countries.
•	Quality Assessments: Conduct robust evaluations of policies and programs to gauge their impact on poverty, healthcare, and labor markets.
•	Data-Driven Decision Making: Utilize data analytics and geospatial data to facilitate targeted and effective policy interventions.
•	Inclusivity and Equity: Focus on gender studies, intra-household inequalities, and social protection to ensure that our assessments and solutions are inclusive and equitable.
•	Global Reach: Expand our impact by engaging with international organizations and governments, particularly in developing countries, to implement effective poverty reduction and social protection strategies.
•	Human Development: Implement innovative interventions and efficient redistributive mechanisms targeting poor, vulnerable, or diseased populations.
•	Policy Assessment and Implementation: Assist international organizations and governments in understanding and assessing the impact of policies and programs.
•	Publication and Knowledge Dissemination: Produce high-quality research publications to further enrich the field of development economics and healthcare.

"""

# %%
print(complete(f"""
memorize the previous output and provide based on that summarization two optimized results following these steps : 
    i need the goals to be better formatted , 
               
    Begin by thinking how to make the goals we defined to be prpject oriented and in the same time a representation of the previous 
               summarization job. 
    provide two exeples of a set of 10 lists numerical 
    
               conclude by provide accuracy rate compared to the summary text {sammary }

               """))
# Out:
# Optimized Result 1:
#
# 1. Implementation of rigorous scientific methods in data analysis and economic health impact assessment.
# 2. Multidisciplinary project development with researchers and health stakeholders.
# 3. Continuous personalized support for performance evaluation and improvement.
# 4. Adherence to ethical guidelines and data security in customer service.
# 5. Innovative data-driven solutions for impact assessment and development assistance programs.
# 6. Collaboration with academic and research institutions for mutual growth.
# 7. Integration of economic theories and empirical data for a comprehensive problem-solving approach.
# 8. Capacity building for national statistical offices and public sector agencies.
# 9. Robust evaluations of policies and programs focusing on poverty, healthcare, and labor markets.
# 10. Promotion of inclusivity and equity through gender studies, intra-household inequalities, and social protection assessments.
#
# Optimized Result 2:
#
# ...

# %%
education = """ •	Ph.D. Economics
•	Ph.D. Physical geography
•	Ph.D. Remote sensing
•	Master's Advanced study
•	Master's Economics
•	Master's Engineering
•	Master's Geographic sciences
•	Master's Geography
•	Master in Econometrics
•	Master in Statistical Methods
"""
project_experience = """ 
•	Canadian Institute for Health Information (CIHI), Ottawa, Program Lead, Physician Databases 2013-
•	Program Consultant, Health Expenditures 2004 to 2013: Managed the development of studies, reports and articles with a health-policy and health human resources lens via in-depth analysis using various Statistics Canada and CIHI data holdings;
•	Participated in the conception, redaction/revision and evaluation of Requests for Proposals/Contracts relative to research projects; Identified resources from various departments in the organization and in partnership with the Team Leads, ensure that these resources are adequately allocated among the portfolio of special analytical studies in order to meet the specific timelines and priority needs of CIHI stakeholders; Contributed to staff development by leading matrix project teams and giving them the opportunity to enhance their knowledge, analytical and writing skills, whether they are under my direct supervision or not; Liaised with other CIHI departments to discuss methodologies, strengths and limitations of data and analytical techniques to be used in products under development and in line with CIHI Strategic Directions; Participated at conferences to facilitate understanding and promote the use of CIHI, products and services.
•	Applied Research and Analysis Directorate (ARAD), Health Canada (Federal Department), Ottawa Economist/Senior Economist 2000-2004: Led the Sustainability project on the Indigenous population as well as the Information and Communication Technology (ICT) project on behalf of the division and the directorate; Coordinated work and workload of project teams to ensure that medium to long-term priorities of the division/directorate and short-term priorities from Senior Officials of the department are smoothly met; Liaised with internal and external stakeholders for joint collaboration, supervision of co-op student work, conference-related or inter-departmental activities; Studied, within a joint work plan and research team, the issue of the sustainability of the Canadian health care system and the role of ICT in the provision of health services. 
•	Center for Interuniversity Research and Analysis on Organizations (CIRANO), Montreal Research Professional 1998-2000. Built and analyzed a database of more than 300 selected papers and articles on the integrated risk management theme; Designed a framework to analyze Hydro-Quebec investment project in the new context of deregulation and in a world of uncertainty, using the real options approach; Devised, with a teamwork, an integrated risk management model for Hydro-Quebec; Produced and presented point form texts for the implementation of the integrated risk management strategy for Hydro-Quebec.
•	Statistics Canada, Montreal, Surveyor 1997-1998. Executed agricultural surveys; Updated respondents’ files.
•	Ministère de l’Agriculture / École Moyenne d’Agriculture, Agriculture Department / Agricultural Technical School, Artibonite, Haïti, 
•	Manager of the experimental farm and Instructor 1991-1994: Managed the farm to meet the experimental and financial purposes of the institution; Participated in the selection of prospective students (around 25 per cycle) to be trained as Agricultural Technician; Gave theory and practice courses in the context of this training. United Nations Development Program / International Labor Organizations; Hinche, Haïti
•	Micro-Projects local coordinator 1990-1991: Structured and developed 20 self-managed rural organizations groups; Coordinated the whole project cycle from the identification to evaluation phases; the project used a Results-Oriented Reporting System; Supervised 12 field employees; a teamwork management approach was used.
•	Research work-University of Aix-en-Provence Aix-Marseille school of economics (AMSE) April 2018-Sep 2018, Measurement of household behavior in terms of education, well-being and inequality in Niger. Building wellbeing composite indicator via principal component analysis. Non-parametric method. Inegality and poverty via Theil and FGT index
•	Oaxaca decomposition. Tool R, Determinants of the labour supply of females living in a couple via logit/ multinomial logit model. Tools R/Stata.
•	Managing director. Statistical expertise firm monitoring-evaluation and agricultural advisory support (CESSE-ACA). Jan 2017- Dec 2017 1/2 Niger, Consulting, Training of professionals on the analysis of statistical data, Teacher from the first year to the bachelor's level
•	Main domain of research: Earth Observation using Artificial Intelligence 
•	Teaching: Remote sensing, image processing, GIS, spatial analysis, cartography 
•	Mitacs-Tera (PhD project, 2021-2024): Development of an air pollution analysis and warning system based on terrestrial and satellite sensors. 
•	Mitacs-Apexmachina (2 MSc projects, 2020-2021): Support to population census in Africa by applying deep learning to HR and THR satellite images. 
•	Mitacs-Xeos (postdoc, 2021): Development of a deep learning algorithm for 3D modeling of buildings from aerial photographs and lidar data. 
•	Mitacs-Xeos (postdoc, 2020-2021): Development of a system for automatic detection of parallax errors in stereoscopic models. 
•	Mitacs-Xeos (postdoc, 2020-2021): Development of a deep learning airborne lidar point cloud classification algorithm. 
•	Mitacs-Effigis (MSc projects, 2020-2021): VHR satellite imagery analysis using deep learning: application to object detection and image segmentation.
•	Mitacs-Effigis (MSc projects, 2020-2021): UHR proximal (drone) imagery analysis using deep learning: application to disease detection in agriculture. 
•	Mitacs-Effigis (PhD project, 2020-2022): Multi-temporal MHR satellite imagery analysis using deep learning: application to natural plants and agricultural crops identification. 
•	Mitacs-Effigis (PhD project, 2020-2022): Development of a methodology for multi-seasonal mapping of riparian strips using big EO data and TempCNN architectures. 
•	Mitacs-Xeos (2020-2021): Detection of errors in airborne photos using deep learning. 
•	Mitacs-Apexmachina (2020): Mapping of poverty based on socio-economic surveys and geospatial data. 
•	CCMEO-NRCan (MSc project, 2019-2021): Classification of airborne lidar point clouds by continuous convolution network. 
•	Mitacs-Rhea Group (PhD project, 2019-2022): BRDF estimation using 6S code and ANNs. 
•	City of Sherbrooke (MSc project, 2018-2020): Sidewalks detection and characterization on panoramic images (Google Street View) by deep learning. 
•	GeoImageNet (CANARIE project, 2018-2020): Web platform for annotation and deep learning on VHR satellite imagery. 
•	Environmental Defense Funds (2018): Nitrogen over-fertilization detection using remote sensing. 
•	Canadian Space Agency - Effigis (2018-2019): Intelligent mapping of stable and variable properties of agricultural soils by big-EO data mining. 
•	Agriculture and Agri-Food Canada (2018-2021): Reduction of GHG through crop monitoring by remote sensing. 
•	Agriculture and Agri-Food Canada (201-2020): Detection of crop diseases using thermal proximal remote sensing. 
•	Function: Chief Scientist – Earth Observation, Tasks: R&D. Project manager for the following Earth Observation projects: DeepSAT-EOADP (Canadian Space Agency): Application of deep learning to UAV imagery for automatic pest detection in agriculture (03/2017-02/2018), World Bank: Assessment of Technical Rooftop Solar PV Potential in Vietnam (02/2017-11/2017) , SCAN (Agriculture and Agri-Food Canada): R&D services in statistics and geomatics (09/2016-08/2019). 
•	CartoPOL-EOADP (Canadian Space Agency): Cartography of Canadian natural areas of using polarimetric decompositions of Radarsat-2 images (07/2014-03/2017). 
•	MineSAR-EOADP (Canadian Space Agency): Operational use of InSAR data for mining operations closures (05/2013-01/2016). 
•	AgriSAT-EOADP (Canadian Space Agency): The use of EO optical and radar satellites to derive relevant information for agriculture (08/2014-01/2016). 
•	ReauSO-EOADP (Canadian Space Agency): Development of Canadian Wetland Indicators from Radarsat-2 images (04/2013-12/2013). 
•	Nopt (Agriculture and Agri-Food Canada): R&D services for optimal nitrogen fertilization (11/2013-11/2016). 
•	Sea sediments (PWGSC): Monitoring sea sediments concentration using EO data (04/214-08/2015). 
•	SOPFEU-MRN Quebec: Detection of active fires from NOAA-AVHRR data (04/2015-04/2016). 
•	CFI (Canadian Fertilizer Institute): Analysis of nitrogen fertilization databases (07/2014-03/2015). 
•	Look North: Monitoring of mining related infrastructure through the use of radar interferometric technology (04/2013-01/2014). 
•	TLAM-Interferometry (CEATI: Centre for Energy Advancement through Technological Innovation): Use of InSAR technology for power pylons monitoring (06/2013-12/2014). 
•	Hydro-Quebec – Interferometry-2: Use of 2 orbits DInDAR for hydroelectric dam monitoring (01/2015-12/2015). 
•	Hydro-Quebec – Interferometry: Use of DInDAR and PSinSAR for hydroelectric dam monitoring (09/2013-12/2014). 
•	StabMat (Hydro-Quebec research institute): EO data for stability analysis of electric poles (04/2014-11/2014). 
•	RIPS (Canadian Space Agency): Remote sensing for disaster management (04/2013-12/2013).
•	Natural Sciences and Engineering Research Council of Canada – École de Technologie Supérieure: Remote sensing for disaster management (04/2013-12/2015) 
•	Deep learning and satellite imagery (Computer Research Institute of Montreal): Automatic objects identification in very high resolution satellite imagery (06/2015-12/2015). 
•	InSAR-PCI: Testing InSAR software package for PCI Geomatics (06/2015-04/2016). Function: Post-doctorate (full time) Tasks: Remote sensing, statistics, scientific computing, model development, publication. 
•	Projects and accomplishments: (researches that conducted to a declaration of invention) NARCT: North American Regional Corn Trials on Nitrogen Fertilization. 
•	"N Watch" (GRIP – Canadian Space Agency): Nitrogen Requirement Assessment through Crop Observation. 
•	Organic science clusters: Organic production of peat blocks for vegetable seedlings and detection of abiotic and biotic stresses. 
•	SAGES (AAFC): Understanding and predicting nitrogen dynamics in Canadian cropping systems to improve efficiency of nitrogen utilization and reduce environmental losses. 
•	Synetix Inc., Montreal, Québec. Function: Consultant (part time). Tasks: algorithms and software development for Earth Observation applications. Projects and accomplishments: CPTAQ (Quebec gov.): automatic map updating using Radarsat-1 images. MRNQ (Quebec gov.): development of software (sigma0) for automatic map updating using optic and radar satellite images. 
•	Renewable Energy Development Centre, Algiers, Algeria (www.cder.dz). Function: Research assistant (full time). Tasks: assessment of renewable energy resources from in-situ and satellite data, publication. Projects and accomplishments: New Solar Atlas of Algeria. Stochastic modelling of solar radiation. 
•	Postdoctoral Fellow : Participation in research activities on the risk of commercial real estate
•	Research Assistant : Ministère des Finances du Québec, Direction de la Forecasting des Revenus Autonome : Development of new econometric models for forecasting prices and volumes of petroleum products (gasoline and diesel); Forecast of revenues from the specific fuel tax; Programming models on statistical software.
•	Department of Finance, Insurance and Real Estate, Université Laval, Data analysis of IPOs (Initial Public Offerings) of Real Estate Investment (REITs); Programming and development of codes for the study of the specific risk of real estate investment firms in connection with the IPO cycle. Department of Finance, Insurance and Real Estate, Université Laval
•	Summer and Fall 2018 : Programming and code development for econometric smoothing models, (unsmoothing) and data analysis of real estate assets. International Food Policy Research Institute (IFPRI) – Senegal February to June 2014  Study of a policy of rice self-sufficiency in the countries of the Economic Community of Enterprises
•	West African States (ECOWAS); Processing and Analysis of national survey databases and administrative secondary data; Programming and development of econometric models.
•	Research and Training Centre for Economic and Social Development (CREFDES) – Senegal July to October 2013. Design of a survey on economic activities, health and the environment in 
•	The World Bank: 2010 – Analytical work on vulnerability and poverty in Haiti (LAC – Social Protection Sector) (data analysis). 2012 – Casamance Youth Employment Assessment (participation in questionnaire design, data entry program, data cleaning and data analysis). 2013 – Migration in Southern Africa (data analysis). 2014 – Haiti Poverty Assessment (data analysis). United Nations Development Program, 2014 - Regional Study on the Social Economic Impact of the Ebola outbreak in West Africa (literature review, data collection and coding). Liberia Institute of Statistics and Geo-Information Services (LISGIS). 2015 – International Data Cleaning Specialist for the Household Income and Expenditure Survey 2014-2015
•	Inter-American Development Bank: 2015- Evaluation of the “Second Low Income Settlement Program” in Guyana (data cleaning and data analysis).
•	2014- Heterogenous Impacts of PROGRESA/OPORTUNIDADES on households' sensitivity to shocks in Mexico (data analysis and coding).
•	• 2015- Fiscal study on the Concentration of spending in hospital-based healthcare in Canada. (Work on Canadian public healthcare insurance data). Production Partnership in Agriculture Project (PPAP), 2017- Household survey for small-scale coffee and cocoa producers in Papua New Guinea (survey design, data cleaning and data analysis)
•	Laval University: 2019- Preparation and statistical work on Quebec healthcare data (data cleaning and data analysis) 
•	Analyst (intern) Analysis Group Inc. May 2008 to Dec. 2008. Assisting in health economics-related studies and litigation; Participation in database treatment, information search and manuscript redaction; Work with insurance databases, clinical trial data and other medical databases.
•	Consultant, World Bank, Education Global Practice, Washington DC, USA 2020 – 2021
•	Research Assistant, Université Laval, Economics Department, Canada 2019 – 2021
•	Research Assistant, Université Laval, Finance Department, Canada Sep-Dec 2019
•	Teaching assistant (Econometrics, Graduate students), Université Laval, Canada Sep-Dec 2017
•	AI/Deep Learning Intern: Designed and implemented a robust Deep Neural Network (DNN) using PyTorch library for BRDF characterization. Worked with multi-sensor remote sensing data stored on different cloud computing platforms to prepare data for developed deep learning model. Implemented different CNN architecture, poling, activation function to improve the accuracy of BRDF modeling. Interacted and ccollaborated with an interdisciplinary researcher’s team to develop more effective and high-impact deep learning model. 
•	Remote Sensing/Big data Intern : Assessment of geospatial cloud-computing platforms, including Google Earth Engine (GEE), Amazon Web Services (AWS), Planetary Computer Microsoft) and Open Data Cube (ODP) in different application of remote sensing. Harmonizing cloud-based multi-sensor remote sensing observation to use in big data application of remote sensing. Experienced with common Machine Learning (ML) algorithms, including SVM, Random Forest (RF) and Decision Tree. Worked with multi-temporal Sentinel-2A and 2B observations to use in the project of drought and flood mitigation service (DFMS) 
•	Research fellow, University of Sherbrooke, 2016 – , Sherbrooke, Canada
•	Postdoc fellow, University of Sherbrooke, 2013 – 2015, Sherbrooke, Canada
•	Consultant, WTO & UN, 2011 – 2012, Geneva, Switzerland
•	Assistant, University of Lausanne, 2006 – 2011, Lausanne, Switzerland
•	High school teacher, Beijing Huijia Private School, 2004 – 2006, Beijing, China

"""
identity  = complete(f"""

Instruction : - step 1 : Summarize the text provide in here {education}. 
            step 2 :  present the a description of the skills , fields base on {education}.
            step3 : based on the {project_experience} ,  {education } present a summary of our company identify ansd field of interest 
""")
print(identity)
# Out:
# Step 1: The provided text lists a series of advanced academic qualifications in various fields such as Economics, Physical Geography, Remote Sensing, Advanced Study, Engineering, Geographic Sciences, Geography, Econometrics, and Statistical Methods.
#
# Step 2: The skills and fields based on the listed qualifications include advanced understanding of economic theories, principles, and models; expertise in physical geography including understanding of earth systems and processes; proficiency in remote sensing technology and data analysis; advanced study skills including research and critical thinking; engineering skills including problem-solving and technical expertise; knowledge of geographic sciences including spatial analysis and GIS; understanding of geography including physical and human aspects; proficiency in econometrics including economic data analysis and forecasting; and expertise in statistical methods including data collection, analysis, and interpretation.
#
# ...

# %%
skills_one ="""
Labor
Protection
Subsidies
Poverty
Policy
Expenditure
Evaluation
Programs
Census
Analysis
Education
Employment
Income
Child
Survey
Software
Price
Gender
Data
Urban
Statistics
Energy
Econometric
Design
Economic
Equity
Resolution
Development
Implementation
Market
Management
Validation
Agriculture
Assets
AI (Artificial Intelligence)
Vulnerability
Migration
Spending
Social
Inequality"""

skills_two = """
1. Agriculture
2. Analysis
3. Applied geomatics
4. Artificial Intelligence
5. Assets
6. Automated recognition
7. AI
8. Bargain
9. Capacity building
10. Census
11. Child
12. Data
13. Design
14. Development
15. Economic
16. Econometric
17. Education
18. Employment
19. Energy
20. Equity
21. Evaluation
22. Expenditure
23. Finance
24. Gender
25. Geographic Information
26. GIS
27. Health economics
28. Hygiene
29. Image
30. Implementation
31. Income
32. Information Technology
33. Inequality
34. Labor
35. Machine Learning
36. Management
37. Market
38. Migration
39. ML
40. Optimization
41. Policy
42. Poverty
43. Price
44. Programs
45. Protection
46. Public policy
47. Remote sensing
48. Resolution
49. Resource mobilization
50. Rural support
51. Sanitation
52. Social
53. Social transfers
54. Software
55. Spending
56. Statistics
57. Subsidies
58. Supervised learning
59. Sustainable
60. Survey
61. Tax
62. Urban
63. Validation
64. Vulnerability
65. Water
66. Well-being
"""

results_completion = complete(f""" 

step 1 :  Start by comparing these texts {skills_one} and {skills_two} with the original text in here {project_experience} . 
step 2 : select the most unique skills in both an create a new list. 
output  : numeric list , unique
    """) 
print(results_completion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Manel\OneDrive\Nouveau dossier\index.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Manel/OneDrive/Nouveau%20dossier/index.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> skills_one ="""
#       <a href='vscode-notebook-cell:/c%3A/Users/Manel/OneDrive/Nouveau%20dossier/index.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> Labor
#       <a href='vscode-notebook-cell:/c%3A/Users/Manel/OneDrive/Nouveau%20dossier/index.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> Protection
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Manel/OneDrive/Nouveau%20dossier/index.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a> Social
#      <a href='vscode-notebook-cell:/c%3A/Users/Manel/OneDrive/Nouveau%20dossier/index.ipynb#W6sZmlsZQ%3D%3D?line=40'>41</a> Inequality"""
# ...

# %%
import pandas as pd 
def compare(skills_one, skills_two) : 

   # Remove any numbering and extra spaces, and then split each string by newlines
    skills_one_list = skills_one.strip().split('\n')
    skills_two_list = [x.split('. ')[-1] for x in skills_two.strip().split('\n')]

    # Convert the list to a set for both skills_one and skills_two
    skills_one_set = set(skills_one_list)
    skills_two_set = set(skills_two_list)

    # Perform a union operation on the sets to get all unique skills
    unique_skills = skills_one_set.union(skills_two_set)

# Create a numeric list
    numeric_unique_skills = [(i+1, skill) for i, skill in enumerate(unique_skills)]

    df =pd.DataFrame(numeric_unique_skills,  columns=['Index', 'Skill'])
    df.to_csv('another.csv', index=False)
    # print(result)
    df.reset_index(drop=True)
compare(skills_one, skills_two)

# %%
countries = [
    "Algeria", "Armenia", "Australia", "Benin", "Botswana", "Burkina Faso",
    "Cambodia", "Cameroon", "Canada", "Chad", "Chile", "China", "Congo",
    "Côte d'Ivoire", "Djibouti", "Dominica", "Dominican Republic", "El Salvador",
    "Ethiopia", "Finland", "France", "Gabon", "Gambia", "Germany", "Ghana",
    "Guatemala", "Guinea", "Guinea-Bissau", "Guyana", "Haiti", "Iceland",
    "India", "Iraq", "Kyrgyzstan", "Liberia", "Luxembourg", "Madagascar",
    "Malawi", "Mali", "Mauritania", "Mauritius", "Mexico", "Mongolia", "Myanmar",
    "Nepal", "Netherlands", "Niger", "Nigeria", "Pakistan", "Panama",
    "Papua New Guinea", "Poland", "Rwanda", "Senegal", "Sierra Leone", "Sudan",
    "Switzerland", "Thailand", "Togo", "Tunisia", "Uganda", "Yemen", "", "", "", "", ""
]

degrees = [
    "Ph.D. Economics",
    "Ph.D. Physical geography",
    "Ph.D. Remote sensing",
    "Master's Advanced study",
    "Master's Economics",
    "Master's Engineering",
    "Master's Geographic sciences",
    "Master's Geography",
    "Master in Econometrics",
    "Master in Statistical Methods"
]

goals = [
    "Rigorous scientific approach in data analysis and health economic impact assessment.",
    "Collaborative project development within the research and health stakeholder community.",
    "Personalized support for continuous performance evaluation and enhancement.",
    "Prioritization of ethics and data security in customer interactions.",
    "Creation of innovative, data-driven solutions for impact assessment and targeted development programs.",
    "Academic and research collaborations, particularly with institutions from developing countries.",
    "Multidisciplinary approach combining economic theories, empirical data, and sectoral knowledge.",
    "Capacity enhancement of national statistical offices and public sector agencies for effective data handling.",
    "Quality assessments of policies and programs to measure their impact on poverty, healthcare, and labor markets.",
    "Focus on inclusivity and equity through targeted studies and assessments in gender, intra-household inequalities, and social protection."
]

# %%
"""Summarize the project based on exemple provide """


print(complete(f""" 

compare this  text :  
SDG Poverty Maps, Simulations for Equity in Education, Social Protection & Jobs
 – Public Expenditure Review, Social Protection and Poverty Issues, Social Protection
   Public Expenditure Review, Social Safety Nets Assessment, Social Sector Incidence 
   Analysis, Social protection project, Socio-Economic Impact of Ebola Virus Disease 
   in West African Countries, Sudan PRSP, Sudan Statistical Project, Support for the
     Universal Social Protection System, Survey, - GeoAI : We use socio-demographic 
     and health surveys, censuses and geospatial data to predict the socio-economic 
     and health status of individuals and improve program targeting.,
       - Pilot survey for targeting Economically Weak Gabonese, Gabon, 2020.,
         - Low income settlement progam beneficiaries survey (LISPBS),
           Co-operative Republic of Guyana, 2015., - Survey on youth employment 
           in the Saint-Louis region (EEJSL), Senegal, 2012., 
           - Casamance Youth Employment Survey (ECEJ), Senegal, 2012.,
             - Survey on Household Living Conditions After Earthquake (ECVMAS), 
             Haiti, 20, - Vulnerability characterization survey in precarious 
             urban settlements in the metropolitan area of San Salvador, El Salvador,
               2011, 2013 and 2019 (panel data)., - Statistics Canada, Montreal,
                 Surveyor 1997-1998., Targeting Health and Social Programs,
                   Targeting Methods, Training in Statistics, Urban Poverty,0
                     Vulnerability Characterization of the Metropolitan Area 0
                     of San Salvador, WASH, - Lead consultant on a research project
                       about the rise of agricultural wage employment in
                         Tanzania, Youth Employment and Productivity Study 

with this one :  1. AAA on Human Capital and Social Policies for Good Quality Job Creation in Central America
2. Assessment of Social Safety Nets
3. Assessment of Social Safety Nets
4. Assessment of Youth Employment Opportunities in Senegal’s Agricultural Sector
5. Benin CWIQ Survey
6. Benefit Incidence Analysis
7. Casamance Youth Employment Assessment
8. Census (RGEF2) planification and monitoring
9. Child Labour
10. Child Labour & Education
11. Child Labour & Education
12. Community Census
13. Cotton Sector Reform
14. Country Economic Memorandum
15. Country Economic Memorandum
16. Education Issues
17. Education, Health, Assets and Employment in Cameroon
18. Effect of Mobile Phone on Socioeconomic Outcomes
19. Gender Impact Evaluation of the “Second Low Income Settlement Program”
20. Gender Issues
21. Gender-Differentiated Labor Allocation in Agriculture Study and PPAP Impact Evaluation
22. Geography of Food Crisis in Africa
23. Ghana Living Standard Survey V
24. Ghana Social Accounting Matrix
25. Health Sector Impact Evaluations
26. Health Service Delivery Indicators Program
27. Household Income Expenditure Project and National Economic Crisis
28. Household Survey
29. Household Survey of Living Conditions Post-Earthquake
30. Household Survey on Poverty Perception
31. Impact Evaluation of the Benin Social Funds
32. Impact Evaluation of the Iraq Transport Corridors
33. Lessons Learnt from Africa’s PERSP
34. Labour Market Issues
35. MDG Maps
36. MDG Maps
37. MDG Maps
38. MDG Maps
39. Migration and Labour Market Issues
40. Mid-Term Impact Evaluation of PPAP
41. Myanmar Living Conditions Survey
42. National Strategy of Social Protection
43. National Strategy of Social Protection
44. NSO Capacity Building
45. Planification Géo Spatiale
46. Poverty Analysis
47. Poverty Analysis
48. Poverty Analysis
49. Poverty Assessment
50. Poverty Assessment
51. Poverty Assessment
52. Poverty Maps
53. Poverty Maps
54. Poverty Maps
55. Poverty Maps
56. Poverty Maps
57. Poverty Maps
58. Poverty Maps
59. Poverty Maps
60. Poverty Maps
61. Poverty Perception
62. Poverty Perception
63. Poverty Perception
64. Poverty Profile
65. Poverty Profile
66. Poverty Profile
67. Poverty Profile
68. Poverty Profile
69. Poverty Profile & Maps
70. Poverty Profile and PMT Targeting
71. Poverty Reduction and Economic Management
72. Poverty Targeting
73. Poverty Trends
74. Poverty Trends
75. PRSP
76. Public Spending
77. Rural Vulnerability and Malnutrition Project
78. SDG Indicators
79. SDG Indicators
80. SDG Poverty Maps
81. Simulations for Equity in Education
82. Simulations for Equity in Education
83. Social Protection & Jobs – Public Expenditure Review
84. Social Protection and Poverty Issues
85. Social Protection Public Expenditure Review
86. Social Safety Nets Assessment 
87. Social Sector Incidence Analysis
88. Social Sector Incidence Analysis
89. Social protection project
90. Socio-Economic Impact of Ebola Virus Disease in West African Countries
91. Sudan PRSP
92. Sudan Statistical Project
93. Support for the Universal Social Protection System
94. Survey
95. Survey
96. Targeting Health and Social Programs
97. Targeting Methods
98. Training in Statistics
99. Urban Poverty
100. Vulnerability Characterization of the Metropolitan Area of San Salvador
101. WASH
102. Youth Employment and Productivity Study 

step : extract the unique in both texts based on meaning and reasoning and make a union between them and provide the output 
- for this   GeoAI: Utilization of socio-demographic, health surveys, and geospatial data for predicting socio-economic and health status i do not want to see a definition like , detect the deciplines each time based on the titles and project and provide the topic/teme i want 102 exemple
- i want an optimized reliable output
- remove references, extra definitions follow this  : Social protection project 
- remove any country indication , year of references i just wand to have like a topic , theme like response more than a title for a project , if the title include multiple decipline no problem divide them 
"""))
# Out:
# Based on the given texts, the unique topics/themes extracted are as follows:
#
# 1. SDG Poverty Maps
# 2. Simulations for Equity in Education
# 3. Social Protection & Jobs
# 4. Public Expenditure Review
# 5. Social Protection and Poverty Issues
# 6. Social Safety Nets Assessment
# 7. Social Sector Incidence Analysis
# 8. Socio-Economic Impact of Ebola Virus Disease in West African Countries
# 9. Sudan PRSP
# 10. Sudan Statistical Project
# 11. Support for the Universal Social Protection System
# 12. GeoAI: Utilization of socio-demographic, health surveys, and geospatial data for predicting socio-economic and health status
# 13. Pilot survey for targeting Economically Weak Gabonese
# 14. Low income settlement program beneficiaries survey (LISPBS)
# 15. Survey on youth employment in the Saint-Louis region (EEJSL)
# 16. Casamance Youth Employment Survey (ECEJ)
# 17. Survey on Household Living Conditions After Earthquake (ECVMAS)
# ...

# %%
projects = [
    "Child Labour",
    "Education Issues",
    "Effect of Mobile Phone on Socioeconomic Outcomes",
    "Gender Impact Evaluation of the 'Second Low Income Settlement Program'",
    "Gender Issues",
    "Gender-Differentiated Labor Allocation in Agriculture Study and PPAP Impact Evaluation",
    "Geography of Food Crisis in Africa",
    "Ghana Living Standard Survey V",
    "Ghana Social Accounting Matrix",
    "Health Sector Impact Evaluations",
    "Health Service Delivery Indicators Program",
    "Household Income Expenditure Project and National Economic Crisis",
    "Household Survey of Living Conditions Post-Earthquake",
    "Household Survey on Poverty Perception",
    "Impact Evaluation of the Benin Social Funds",
    "Impact Evaluation of the Iraq Transport Corridors",
    "Labour Market Issues",
    "MDG Maps",
    "Migration and Labour Market Issues",
    "Mid-Term Impact Evaluation of PPAP",
    "Myanmar Living Conditions Survey",
    "National Strategy of Social Protection",
    "NSO Capacity Building",
    "Planification Géo Spatiale",
    "Poverty Analysis",
    "Poverty Assessment",
    "Poverty Maps",
    "Poverty Perception",
    "Poverty Profile",
    "Poverty Profile & Maps",
    "Poverty Profile and PMT Targeting",
    "Poverty Reduction and Economic Management",
    "Poverty Targeting",
    "Poverty Trends",
    "PRSP",
    "Public Spending",
    "Rural Vulnerability and Malnutrition Project",
    "SDG Indicators",
    "Social Sector Incidence Analysis",
    "Social protection project",
    "Socio-Economic Impact of Ebola Virus Disease in West African Countries",
    "Sudan PRSP",
    "Sudan Statistical Project",
    "Support for the Universal Social Protection System",
    "Targeting Health and Social Programs",
    "Targeting Methods",
    "Training in Statistics",
    "Urban Poverty",
    "Vulnerability Characterization of the Metropolitan Area of San Salvador",
    "WASH",
    "Youth Employment and Productivity Study",
    "SDG Poverty Mapping",
    "Simulations for Equity in Education",
    "Social Protection & Jobs - Public Expenditure Review",
    "Social Protection and Poverty Issues",
    "Social Safety Nets Assessment",
    "Social Sector Incidence Analysis",
    "Socio-Economic Impact of Ebola Virus Disease",
    "Sudan PRSP",
    "Sudan Statistical Project",
    "Support for Universal Social Protection System",
    "GeoAI Utilization",
    "Pilot survey for targeting Economically Vulnerable Individuals",
    "Low Income Settlement Program Beneficiaries Survey",
    "Youth Employment Survey",
    "Casamance Youth Employment Survey",
    "Survey on Household Living Conditions After Earthquake"
]

print(len(projects))
# Out:
# 67

# %%
new_columns_input = pd.DataFrame({
    'projects' : projects, 
})

df_new= pd.read_csv('another.csv', delimiter=',', encoding='utf-8', index_col=None)
df_new['Country'] = countries
df_nn = pd.concat([df_new,new_columns_input], axis=1)
df_nn.to_csv('text.csv', index=False)

# %%
def  cretaeCSSV(file, outer, name, val  ): 
    new_columns_input = pd.DataFrame({
        name : val, 
    })

    df= pd.read_csv(file, delimiter=',', encoding='utf-8', index_col=None)
    df['Country'] = countries
    df_new = pd.concat([df,new_columns_input], axis=1)
    df_new.to_csv(outer,  index=False)
    return   df_new

# %%
cretaeCSSV('text.csv', 'tested.csv', 'goals', goals)
cretaeCSSV('text.csv', 'tested.csv', 'education', degrees)
# Out:
#     Index                   Skill    Country  \
# 0       1       Applied geomatics    Algeria
# 1       2                   Water    Armenia
# 2       3                   Price  Australia
# 3       4                Programs      Benin
# 4       5                     Tax   Botswana
# ..    ...                     ...        ...
# 62     63              Inequality
# 63     64              Management
# 64     65  Information Technology
# 65     66                     GIS
# 66     67              Employment
#
#                                              projects  \
# 0                                        Child Labour
# 1                                    Education Issues
# 2    Effect of Mobile Phone on Socioeconomic Outcomes
# 3   Gender Impact Evaluation of the 'Second Low In...
# 4                                       Gender Issues
# ..                                                ...
# 62  Pilot survey for targeting Economically Vulner...
# ...
